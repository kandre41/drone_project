# %%
import torch

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("weights\yolo11x-pose.pt")  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data="settings\coco8-pose.yaml", epochs=100, imgsz=640)
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\y'
# <>:7: SyntaxWarning: invalid escape sequence '\c'
# <>:4: SyntaxWarning: invalid escape sequence '\y'
# <>:7: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\andre\AppData\Local\Temp\ipykernel_21324\680287038.py:4: SyntaxWarning: invalid escape sequence '\y'
#   model = YOLO("weights\yolo11x-pose.pt")  # load a pretrained model (recommended for training)
# C:\Users\andre\AppData\Local\Temp\ipykernel_21324\680287038.py:7: SyntaxWarning: invalid escape sequence '\c'
#   results = model.train(data="settings\coco8-pose.yaml", epochs=100, imgsz=640)
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\andre\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
import cv2

# %%
#del model
del results

# %%
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("PyTorch CUDA cache cleared.")
# Out:
# PyTorch CUDA cache cleared.

# %%
import gc

# Run Python garbage collection
gc.collect()
print("Python garbage collector invoked.")
# Out:
# Python garbage collector invoked.

# %%
from ultralytics import YOLO
model = YOLO("weights\yolo11x-pose.pt")
model.export(format='engine')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\y'
# <>:2: SyntaxWarning: invalid escape sequence '\y'
# C:\Users\andre\AppData\Local\Temp\ipykernel_7872\1968444081.py:2: SyntaxWarning: invalid escape sequence '\y'
#   model = YOLO("weights\yolo11x-pose.pt")
# WARNING TensorRT requires GPU export, automatically assigning device=0
# Ultralytics 8.3.237  Python-3.12.12 torch-2.9.1+cu130 CUDA:0 (NVIDIA GeForce RTX 5090 Laptop GPU, 24463MiB)
# YOLO11x-pose summary (fused): 199 layers, 58,751,308 parameters, 0 gradients, 202.8 GFLOPs
#
# PyTorch: starting from 'weights\yolo11x-pose.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 56, 8400) (113.0 MB)
#
# ONNX: starting export with onnx 1.19.1 opset 20...
# ONNX: slimming with onnxslim 0.1.79...
# ONNX: export success  3.5s, saved as 'weights\yolo11x-pose.onnx' (224.6 MB)
#
# TensorRT: starting export with TensorRT 10.14.1.48.post1...
# TensorRT: input "images" with shape(1, 3, 640, 640) DataType.FLOAT
# ...
