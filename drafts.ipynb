# %%
from DJITelloPy.djitellopy import tello

# %%
drone=tello.Tello()
drone.connect()
# Out:
# [INFO] tello.py - 131 - Tello instance was initialized. Host: '192.168.10.1'. Port: '8889'.
# [INFO] tello.py - 450 - Send command: 'command'
# [INFO] tello.py - 474 - Response command: 'ok'

# %%
drone.takeoff()
# Out:
# [INFO] tello.py - 450 - Send command: 'takeoff'
# [INFO] tello.py - 474 - Response takeoff: 'ok'

# %%
drone.land()
# Out:
# [INFO] tello.py - 450 - Send command: 'land'
# [INFO] tello.py - 474 - Response land: 'ok'

# %%
drone.get_battery()
# Out:
# 57
